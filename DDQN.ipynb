# %%
import gym
import math
import random
import tqdm
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple
from collections import deque
from itertools import count
from copy import deepcopy
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T
from torch.distributions import Categorical

# создаем энвайронмент с игрой
env = gym.make('BreakoutDeterministic-v4').unwrapped

# настраиваем matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display    
print("Is python : {}".format(is_ipython))

# выбираем девайс для игры
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device : {}".format(device))

# запоминаем, сколько действий в игре
ACTIONS_NUM = env.action_space.n
print("Number of actions : {}".format(ACTIONS_NUM))
# Out:
# Is python : True
# Device : cuda
# Number of actions : 4

# %%
STATE_SIZE = 4
STATE_W = 84
STATE_H = 84
MEMSIZE = 200000

# Задание 1. Необходимо реализовать класс для хранения состояния игры. 
# В качестве последнего мы будем использовать состеканные 4 последовательных кадра игры.
# Это необходимо, чтобы агент понимал скорости и ускорения игровых объектов.
    
class StateHolder:
    
    def __init__(self, number_screens=4):
        self.first_action = True
        self.state = torch.ByteTensor(1, 84, 84).to(device)
        self.number_screens = number_screens
        
    def push(self, screen):
        new_screen = screen.squeeze(0)
        if self.first_action:
            self.state[0] = new_screen
            for number in range(self.number_screens-1):
                self.state = torch.cat((self.state, new_screen), 0)
            self.first_action = False
        else:
            self.state = torch.cat((self.state, new_screen), 0)[1:]
    
    def get(self):
        return self.state.unsqueeze(0)

    def reset(self):
        self.first_action = True
        self.state = torch.ByteTensor(1, 84, 84).to(device)
    
Transition = namedtuple('Transition',('state', 'action', 'next_state', 'reward'))


class ReplayMemory:

    def __init__(self, capacity = MEMSIZE):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, *args):
        #Положить переход в память
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        #Получить сэмпл из памяти
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
# Задание 2. Собрать архитектуру сети (DQN).
# В качестве примера можно использовать сеть вида:
# Conv(4->32) -> Conv(32->64) -> Conv(64->64) -> FC(512) -> FC(ACTIONS_NUM)
# В качестве функций активации необходимо использовать ReLU(но совершенно не обязательно ими ограничиваться)
# Attention : не забудьте правильно инициализировать веса, это важно для данной задачи!
class DuelingDQN(nn.Module):
    def __init__(self):
        super(DuelingDQN, self).__init__()
        self.conv1 = nn.Conv2d(4, 32, kernel_size=8, stride=4)
        nn.init.kaiming_normal_(self.conv1.weight, nonlinearity='relu')
        nn.init.constant_(self.conv1.bias, 0)
        
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        nn.init.kaiming_normal_(self.conv2.weight, nonlinearity='relu')
        nn.init.constant_(self.conv2.bias, 0)
        
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        nn.init.kaiming_normal_(self.conv3.weight, nonlinearity='relu')
        nn.init.constant_(self.conv3.bias, 0)
        
        self.conv4 = nn.Conv2d(64, 1024, kernel_size=7, stride=1)
        nn.init.kaiming_normal_(self.conv4.weight, nonlinearity='relu')
        nn.init.constant_(self.conv4.bias, 0)
        # add comment
        self.fc_value = nn.Linear(512, 1)
        nn.init.kaiming_normal_(self.fc_value.weight, nonlinearity='relu')
        self.fc_advantage = nn.Linear(512, 4)
        nn.init.kaiming_normal_(self.fc_advantage.weight, nonlinearity='relu')
        
    def forward(self, x):
        x = x/255 
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        # add comment
        x_value = x[:,:512,:,:].view(-1,512)
        x_advantage = x[:,512:,:,:].view(-1,512)
        x_value = self.fc_value(x_value)
        x_advantage = self.fc_advantage(x_advantage)
        # add comment
        q_value = x_value + x_advantage.sub(torch.mean(x_advantage, 1)[:, None])
        return q_value

# %%
# Тут блок с кодом, генерирующим 1 кадр игры
# Обратите внимание, что выходным тензора является torch.ByteTensor со значениями 0-255
# Это сделанно намеренно для экономии места(4х экономия по сравнению с FloatTensor)
# Подумайте, где и как необходимо совершать преобразование ByteTensort -> FloatTensor, чтобы его можно было подавать в сеть. 

resize = T.Compose([T.ToPILImage(),
                    T.Resize( (STATE_W, STATE_H), interpolation=Image.CUBIC),
                    T.ToTensor()])

def get_screen():
    screen = env.render(mode='rgb_array')
    screen = np.dot(screen[...,:3], [0.299, 0.587, 0.114])
    screen = screen[30:195,:]
    screen = np.ascontiguousarray(screen, dtype=np.uint8).reshape(screen.shape[0],screen.shape[1],1)
    return resize(screen).mul(255).type(torch.ByteTensor).to(device).detach().unsqueeze(0)

env.reset()
plt.figure()
plt.imshow(get_screen().cpu().reshape(-1,84).numpy(),
           interpolation='none', cmap = 'gray')
plt.title('Example extracted screen')
plt.colorbar()
plt.show()

# %%
# Далее стандартный метод для выбора нового действия из лекции

policy_net = DuelingDQN().to(device)
target_net = DuelingDQN().to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr=1e-4)

def select_action(state, eps_threshold):
    global steps_done    
    sample = random.random()
    if sample > eps_threshold and state is not None:
        with torch.no_grad():
            return policy_net(state.float()).max(1)[1].view(1, 1)
    else:
        return torch.tensor([[random.randrange(ACTIONS_NUM)]], device=device, dtype=torch.long)

mean_size = 100
mean_step = 1
train_rewards = []

# %%
def plot_rewards(rewards = train_rewards, name = "Train"):
    plt.figure(2)
    plt.clf()
    plt.title(name)
    plt.xlabel('Episode')
    plt.ylabel('Duration')
    plt.plot(rewards)
    # Строим график среднего вознаграждения по 100 последним эпизодам
    if len(rewards) > mean_size:
        means = np.array([rewards[i:i+mean_size:] for i in range(0, len(rewards) - mean_size, mean_step)]).mean(1)
        means = np.concatenate((np.zeros(mean_size - 1), means))
        plt.plot(means)
    plt.show()

# %%
# Еще немного методов из лекции

BATCH_SIZE = 32
GAMMA = 0.99

def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    # выбираем новый батч
    transitions = memory.sample(BATCH_SIZE)
    batch = Transition(*zip(*transitions))

    # Для всех состояний считаем маску не финальнсти и конкантенируем их
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.uint8)

    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None]).float().to(device) 
    state_batch = torch.cat(batch.state).float().to(device)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)
    
    # Считаем Q(s_t, a) - модель дает Q(s_t), затем мы выбираем
    # колонки, которые соответствуют нашим действиям на щаге
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # Подсчитываем ценность состяония V(s_{t+1}) для всех последующмх состояний.
    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    next_state_action = policy_net(non_final_next_states).detach().max(1)[1].view(-1,1)
    next_state_values[non_final_mask] = target_net(non_final_next_states).detach().gather(1, next_state_action).view(-1) # берем значение максимума
    
    # Считаем ожидаемое значение функции оценки ценности действия  Q-values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Считаем ошибку Huber loss
    loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))
    
    # Оптимизация модели
    optimizer.zero_grad()
    loss.backward()
    for param in policy_net.parameters():
        param.grad.data.clamp_(-1, 1)
    optimizer.step()
    
    del non_final_mask
    del next_state_action
    del non_final_next_states
    del state_batch
    del action_batch
    del reward_batch
    del state_action_values
    del next_state_values
    del expected_state_action_values
    del loss

# %%
# количество эпизодов, которые играем
NUM_EPISODES = 2000

# количество кадров, между которыми обучаем модель
OPTIMIZE_MODEL_STEP = 4
# количество кадров, между которыми обновляем target-модель
TARGET_UPDATE=10000

# несколько шагов для разогрева модели()
STEPS_BEFORE_TRAIN = 50000

# параметры для e-greedy стратегии выбора действия
EPS_START = 1
EPS_END = 0.1
EPS_DECAY = 1000000 
eps_threshold = EPS_START

policy_net.train()
target_net.eval()

state_holder = StateHolder()
memory = ReplayMemory()
test_rewards = []
train_rewards = []

# Общее число 
steps_done = 0
optimizer = optim.Adam(policy_net.parameters(), lr=0.00001)

# %%
'''resume = True

if resume:
    checkpoint = torch.load('policy_net.tar')
    policy_net.load_state_dict(checkpoint['policy_net_state_dict'])
    checkpoint = torch.load('target_net.tar')
    target_net.load_state_dict(checkpoint['target_net_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    checkpoint = torch.load('eps,steps,rew.tar')
    eps_threshold = checkpoint['eps']'''
# Out:
# "resume = True\n\nif resume:\n    checkpoint = torch.load('policy_net.tar')\n    policy_net.load_state_dict(checkpoint['policy_net_state_dict'])\n    checkpoint = torch.load('target_net.tar')\n    target_net.load_state_dict(checkpoint['target_net_state_dict'])\n    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])\n    checkpoint = torch.load('eps,steps,rew.tar')\n    eps_threshold = checkpoint['eps']"

# %%
# Задание 3. Заполнить пропуски в нижеприведенном коде.
#optimizer = optim.Adam(policy_net.parameters(), lr=0.000001)
NUM_EPISODES = 50000
for e in tqdm.tqdm_notebook(range(NUM_EPISODES)):
    env.reset()
    lives = 5
    ep_rewards = []
    state_holder.push(get_screen())
    
    for t in count():
        state = state_holder.get()
        # Рассчет eps_threshold'а для e-greedy
        eps_threshold = EPS_END + (EPS_START - EPS_END) * math.exp(-1. * steps_done / EPS_DECAY)
        action = select_action(state, eps_threshold)
        steps_done += 1
        
        # Шаг одного кадра игры 
        _, reward, done, info = env.step(action.item())
        life = info['ale.lives']
        ep_rewards.append(reward)
        reward = torch.tensor([reward], device=device)
        # где:
        # reward - награда, полученная в рамках последнего действия
        # done - флаг окончания эпизода
        # info - важная системная информация
        state_holder.push(get_screen())
        next_state = state_holder.get()
        # Код обработки перехода
        # Работа с ReplayMemory
        if not done:
            new_reward = reward
            next_state, lives = (None, life) if life < lives else (next_state, lives)
            memory.push(state.to('cpu'), action, next_state, new_reward)
            state = next_state
        else:
            next_state = None
            new_reward = torch.zeros_like(reward)
            memory.push(state.to('cpu'), action, next_state, new_reward)
            state = next_state
        
        # Задание 3.1. Необходимо дополниь код следующим трюком, который значительно
        # улучшает сходимость обучения. В случае, если эпизод не закончился, но агент на 
        # очередном шаге потерял жизнь, то такой переход надо класть в ReplayMemory как финальный.
        # При этом, необходимо далее продолжать эпизод игры, пока не получите done == True
        # Тет самым вы научите агента понимать, что терять жизни по дороге - плохо.
        
        # Шаг оптимизации
        if (steps_done > STEPS_BEFORE_TRAIN) and steps_done % OPTIMIZE_MODEL_STEP == 0:
            BATCH_SIZE = 32
            optimize_model()
        if e % 100 == 99 and  t == 0:
            print('\neps_threshold:', eps_threshold)
            print('steps_done: ', steps_done)
            # Средний reward по последним 100 эпизодам
            print("Mean score : {}".format(np.mean(train_rewards[-100:])))
        if e % 10 == 9 and  t == 0:
            print("10 ep.mean score : {}".format(np.mean(train_rewards[-10:])))
        if t > 18000:
            break
        # Шаг обновления target'сети
        if steps_done % TARGET_UPDATE == 0:
            print("Target net updated!")
            target_net.load_state_dict(policy_net.state_dict())
        
        # Код завершающий эпизод игры/обучения
        if done:
            train_rewards.append(np.sum(ep_rewards))
            break
# Out:
# 10 ep.mean score : 0.8888888888888888
# 10 ep.mean score : 0.8
# 10 ep.mean score : 1.1
# 10 ep.mean score : 1.2
# 10 ep.mean score : 0.8
# Target net updated!
# 10 ep.mean score : 1.4
# 10 ep.mean score : 1.2
# 10 ep.mean score : 1.6
# 10 ep.mean score : 0.6
#
# eps_threshold: 0.9844117752815875
# steps_done:  17473
# Mean score : 1.0909090909090908
# 10 ep.mean score : 1.3
# 10 ep.mean score : 1.2
# Target net updated!
# 10 ep.mean score : 1.2
# 10 ep.mean score : 1.6
# 10 ep.mean score : 1.2
# 10 ep.mean score : 0.7
# 10 ep.mean score : 0.5
# 10 ep.mean score : 0.5
# Target net updated!
# 10 ep.mean score : 0.5
# 10 ep.mean score : 0.8
#
# eps_threshold: 0.9693725663155472
# steps_done:  34624
# Mean score : 0.95
# 10 ep.mean score : 1.3
# 10 ep.mean score : 1.4
# 10 ep.mean score : 1.1
# 10 ep.mean score : 0.8
# Target net updated!
# 10 ep.mean score : 1.6
# 10 ep.mean score : 0.6
# 10 ep.mean score : 0.7
# 10 ep.mean score : 1.2
# 10 ep.mean score : 1.1
# Target net updated!
# 10 ep.mean score : 1.1
#
# eps_threshold: 0.9541695952211876
# steps_done:  52266
# Mean score : 1.1
# 10 ep.mean score : 1.4
# 10 ep.mean score : 0.6
# 10 ep.mean score : 0.9
# 10 ep.mean score : 1.2
# 10 ep.mean score : 0.7
# Target net updated!
# 10 ep.mean score : 1.3
# 10 ep.mean score : 1.3
# 10 ep.mean score : 0.7
# 10 ep.mean score : 1.0
# 10 ep.mean score : 1.6
#
# eps_threshold: 0.939200592678683
# steps_done:  69946
# Mean score : 1.07
# 10 ep.mean score : 1.4
# Target net updated!
# 10 ep.mean score : 1.4
# 10 ep.mean score : 1.4
# 10 ep.mean score : 1.3
# 10 ep.mean score : 1.1
# 10 ep.mean score : 1.3
# Target net updated!
# 10 ep.mean score : 0.8
# 10 ep.mean score : 0.6
# 10 ep.mean score : 1.6
# 10 ep.mean score : 1.3
#
# eps_threshold: 0.923980416566544
# steps_done:  88249
# Mean score : 1.2
# 10 ep.mean score : 1.2
# Target net updated!
# 10 ep.mean score : 1.1
# 10 ep.mean score : 1.5
# 10 ep.mean score : 1.2
# 10 ep.mean score : 1.3
# 10 ep.mean score : 1.6
# 10 ep.mean score : 1.1
# Target net updated!
# 10 ep.mean score : 1.0
# 10 ep.mean score : 1.1
# 10 ep.mean score : 1.3
#
# eps_threshold: 0.9087127316442817
# steps_done:  106952
# Mean score : 1.31
# 10 ep.mean score : 1.9
# 10 ep.mean score : 1.1
# Target net updated!
# 10 ep.mean score : 1.9
# 10 ep.mean score : 1.7
# 10 ep.mean score : 1.1
# 10 ep.mean score : 0.8
# 10 ep.mean score : 1.2
# 10 ep.mean score : 0.6
# Target net updated!
# 10 ep.mean score : 1.3
# 10 ep.mean score : 1.2
#
# eps_threshold: 0.8942440353436405
# steps_done:  125005
# Mean score : 1.15
# 10 ep.mean score : 0.6
# 10 ep.mean score : 0.8
# 10 ep.mean score : 1.3
# Target net updated!
# 10 ep.mean score : 1.5
# 10 ep.mean score : 1.2
# 10 ep.mean score : 0.6
# 10 ep.mean score : 0.9
# 10 ep.mean score : 1.0
# 10 ep.mean score : 1.7
# Target net updated!
# 10 ep.mean score : 1.2
#
# eps_threshold: 0.8802651230873711
# steps_done:  142762
# Mean score : 1.11
# 10 ep.mean score : 0.9
# 10 ep.mean score : 1.2
# 10 ep.mean score : 0.8
# 10 ep.mean score : 2.0
# Target net updated!
# 10 ep.mean score : 0.9
# 10 ep.mean score : 1.5
# 10 ep.mean score : 1.1
# 10 ep.mean score : 1.8
# 10 ep.mean score : 1.4
# 10 ep.mean score : 1.0
# Target net updated!
#
# eps_threshold: 0.865965985440367
# steps_done:  161258
# Mean score : 1.26
# 10 ep.mean score : 0.9
# 10 ep.mean score : 0.9
# 10 ep.mean score : 1.2
# 10 ep.mean score : 1.1
# 10 ep.mean score : 0.6
# 10 ep.mean score : 1.0
# Target net updated!
# 10 ep.mean score : 1.3
# 10 ep.mean score : 2.5
# 10 ep.mean score : 0.9
# 10 ep.mean score : 0.8
#
# eps_threshold: 0.852278622012698
# steps_done:  179289
# Mean score : 1.13
# 10 ep.mean score : 1.0
# Target net updated!
# 10 ep.mean score : 1.1
# 10 ep.mean score : 1.4
# 10 ep.mean score : 0.9
# 10 ep.mean score : 1.9
# 10 ep.mean score : 1.2
# Target net updated!
# 10 ep.mean score : 0.9
# 10 ep.mean score : 1.1
# 10 ep.mean score : 2.1
# 10 ep.mean score : 1.2
#
# eps_threshold: 0.8382627295332262
# steps_done:  198096
# Mean score : 1.34
# 10 ep.mean score : 1.6
# 10 ep.mean score : 0.5
# Target net updated!
# 10 ep.mean score : 1.4
# 10 ep.mean score : 1.0
# 10 ep.mean score : 1.0
# 10 ep.mean score : 0.9
# 10 ep.mean score : 1.7
# Target net updated!
# 10 ep.mean score : 1.2
# 10 ep.mean score : 1.6
# 10 ep.mean score : 1.2
#
# eps_threshold: 0.8252009314791077
# steps_done:  215947
# Mean score : 1.11
# 10 ep.mean score : 0.6
# 10 ep.mean score : 1.9
# 10 ep.mean score : 1.4
# Target net updated!
# 10 ep.mean score : 0.8
# 10 ep.mean score : 1.0
# 10 ep.mean score : 1.1
# 10 ep.mean score : 1.8
# 10 ep.mean score : 1.1
# Target net updated!
# 10 ep.mean score : 1.8
# 10 ep.mean score : 1.4
#
# eps_threshold: 0.811568553335078
# steps_done:  234924
# Mean score : 1.33
# 10 ep.mean score : 1.0
# 10 ep.mean score : 1.4
# 10 ep.mean score : 1.5
# Target net updated!
# 10 ep.mean score : 1.4
# 10 ep.mean score : 1.2
# 10 ep.mean score : 1.6
# 10 ep.mean score : 0.9
# 10 ep.mean score : 1.0
# 10 ep.mean score : 1.2
# Target net updated!
# 10 ep.mean score : 0.9
#
# eps_threshold: 0.7985765490563883
# steps_done:  253351
# Mean score : 1.31
# 10 ep.mean score : 2.0
# 10 ep.mean score : 1.4
# 10 ep.mean score : 0.8
# 10 ep.mean score : 1.3
# Target net updated!
# 10 ep.mean score : 1.4
# 10 ep.mean score : 1.4
# 10 ep.mean score : 0.7
# 10 ep.mean score : 1.2
# 10 ep.mean score : 1.5
# 10 ep.mean score : 1.3
# Target net updated!
#
# eps_threshold: 0.785829300261945
# steps_done:  271767
# Mean score : 1.23
# 10 ep.mean score : 1.3
# 10 ep.mean score : 2.6
# 10 ep.mean score : 2.2
# 10 ep.mean score : 1.9
# Target net updated!
# 10 ep.mean score : 2.3
# 10 ep.mean score : 1.4
# 10 ep.mean score : 2.2
# 10 ep.mean score : 1.7
# 10 ep.mean score : 2.2
# Target net updated!
# 10 ep.mean score : 2.2
#
# eps_threshold: 0.7714078411775894
# steps_done:  293019
# Mean score : 2.07
# 10 ep.mean score : 2.0
# 10 ep.mean score : 1.7
# 10 ep.mean score : 1.6
# 10 ep.mean score : 1.6
# Target net updated!
# 10 ep.mean score : 1.5
# 10 ep.mean score : 1.5
# 10 ep.mean score : 1.7
# 10 ep.mean score : 2.6
# 10 ep.mean score : 2.4
# Target net updated!
# 10 ep.mean score : 2.4
#
# eps_threshold: 0.7579531731216451
# steps_done:  313262
# Mean score : 1.88
# 10 ep.mean score : 1.8
# 10 ep.mean score : 1.7
# 10 ep.mean score : 3.0
# 10 ep.mean score : 2.0
# Target net updated!
# 10 ep.mean score : 2.3
# 10 ep.mean score : 4.1
# 10 ep.mean score : 2.3
# 10 ep.mean score : 3.7
# Target net updated!
# 10 ep.mean score : 2.7
# 10 ep.mean score : 2.0
#
# eps_threshold: 0.743025102622731
# steps_done:  336212
# Mean score : 2.66
# 10 ep.mean score : 2.8
# 10 ep.mean score : 2.2
# Target net updated!
# 10 ep.mean score : 2.9
# 10 ep.mean score : 2.1
# 10 ep.mean score : 3.4
# 10 ep.mean score : 2.0
# 10 ep.mean score : 3.2
# Target net updated!
# 10 ep.mean score : 3.2
# 10 ep.mean score : 3.2
# 10 ep.mean score : 2.7
#
# eps_threshold: 0.7282220980899174
# steps_done:  359502
# Mean score : 2.8
# 10 ep.mean score : 3.1
# Target net updated!
# 10 ep.mean score : 3.2
# 10 ep.mean score : 3.1
# 10 ep.mean score : 3.1
# 10 ep.mean score : 4.4
# Target net updated!
# 10 ep.mean score : 2.8
# 10 ep.mean score : 4.3
# 10 ep.mean score : 1.8
# 10 ep.mean score : 2.8
# Target net updated!
# 10 ep.mean score : 2.8
#
# eps_threshold: 0.7127768028325194
# steps_done:  384395
# Mean score : 3.29
# 10 ep.mean score : 4.6
# 10 ep.mean score : 3.9
# 10 ep.mean score : 3.3
# Target net updated!
# 10 ep.mean score : 3.1
# 10 ep.mean score : 3.7
# 10 ep.mean score : 3.9
# Target net updated!
# 10 ep.mean score : 3.6
# 10 ep.mean score : 3.3
# 10 ep.mean score : 3.7
# 10 ep.mean score : 3.5
#
# eps_threshold: 0.6975421129964249
# steps_done:  409571
# Mean score : 3.51
# 10 ep.mean score : 3.1
# Target net updated!
# 10 ep.mean score : 2.0
# 10 ep.mean score : 3.3
# 10 ep.mean score : 4.1
# 10 ep.mean score : 5.2
# Target net updated!
# 10 ep.mean score : 2.5
# 10 ep.mean score : 2.6
# 10 ep.mean score : 4.1
# 10 ep.mean score : 4.6
# Target net updated!
# 10 ep.mean score : 2.8
#
# eps_threshold: 0.6833333246270021
# steps_done:  433637
# Mean score : 3.44
# 10 ep.mean score : 3.2
# 10 ep.mean score : 4.8
# 10 ep.mean score : 3.5
# Target net updated!
# 10 ep.mean score : 2.6
# 10 ep.mean score : 3.2
# 10 ep.mean score : 3.0
# 10 ep.mean score : 2.7
# 10 ep.mean score : 2.8
# Target net updated!
# 10 ep.mean score : 3.6
# 10 ep.mean score : 3.1
#
# eps_threshold: 0.6697979152540483
# steps_done:  457114
# Mean score : 3.29
# 10 ep.mean score : 3.6
# 10 ep.mean score : 2.9
# Target net updated!
# 10 ep.mean score : 4.0
# 10 ep.mean score : 1.9
# 10 ep.mean score : 3.3
# 10 ep.mean score : 3.7
# Target net updated!
# 10 ep.mean score : 4.7
# 10 ep.mean score : 4.6
# 10 ep.mean score : 2.9
# 10 ep.mean score : 3.0
# Target net updated!
#
# eps_threshold: 0.6556067519389803
# steps_done:  482335
# Mean score : 3.52
# 10 ep.mean score : 4.2
# 10 ep.mean score : 2.6
# 10 ep.mean score : 3.9
# 10 ep.mean score : 3.1
# Target net updated!
# 10 ep.mean score : 3.8
# 10 ep.mean score : 2.2
# 10 ep.mean score : 4.5
# 10 ep.mean score : 4.4
# Target net updated!
# 10 ep.mean score : 3.1
# 10 ep.mean score : 3.5
#
# eps_threshold: 0.642466191319535
# steps_done:  506270
# Mean score : 3.4
# 10 ep.mean score : 2.9
# 10 ep.mean score : 4.3
# Target net updated!
# 10 ep.mean score : 3.5
# 10 ep.mean score : 3.4
# 10 ep.mean score : 2.7
# 10 ep.mean score : 3.6
# Target net updated!
# 10 ep.mean score : 3.2
# 10 ep.mean score : 3.4
# 10 ep.mean score : 4.7
# 10 ep.mean score : 3.6
# Target net updated!
#
# eps_threshold: 0.6291234467469652
# steps_done:  531174
# Mean score : 3.63
# 10 ep.mean score : 3.9
# 10 ep.mean score : 2.6
# 10 ep.mean score : 3.3
# 10 ep.mean score : 3.2
# Target net updated!
# 10 ep.mean score : 2.9
# 10 ep.mean score : 3.0
# 10 ep.mean score : 3.5
# 10 ep.mean score : 3.6
# Target net updated!
# 10 ep.mean score : 3.3
# 10 ep.mean score : 4.2
#
# eps_threshold: 0.6165844416177737
# steps_done:  555157
# Mean score : 3.25
# 10 ep.mean score : 2.9
# 10 ep.mean score : 4.0
# Target net updated!
# 10 ep.mean score : 4.2
# 10 ep.mean score : 4.9
# 10 ep.mean score : 5.0
# 10 ep.mean score : 4.1
# Target net updated!
# 10 ep.mean score : 3.3
# 10 ep.mean score : 3.7
# 10 ep.mean score : 4.5
# 10 ep.mean score : 4.8
# Target net updated!
#
# eps_threshold: 0.6028685295763379
# steps_done:  582067
# Mean score : 4.18
# 10 ep.mean score : 3.3
# 10 ep.mean score : 5.2
# 10 ep.mean score : 5.4
# Target net updated!
# 10 ep.mean score : 3.9
# 10 ep.mean score : 4.1
# 10 ep.mean score : 4.7
# 10 ep.mean score : 4.9
# Target net updated!
# 10 ep.mean score : 4.3
# 10 ep.mean score : 3.5
# 10 ep.mean score : 4.0
#
# eps_threshold: 0.5891752273001808
# steps_done:  609675
# Mean score : 4.39
# 10 ep.mean score : 3.9
# Target net updated!
# 10 ep.mean score : 5.0
# 10 ep.mean score : 4.5
# 10 ep.mean score : 4.2
# Target net updated!
# 10 ep.mean score : 4.0
# 10 ep.mean score : 3.2
# 10 ep.mean score : 3.8
# 10 ep.mean score : 4.8
# Target net updated!
# 10 ep.mean score : 3.3
# 10 ep.mean score : 5.1
#
# eps_threshold: 0.5764166389622474
# steps_done:  636103
# Mean score : 4.04
# 10 ep.mean score : 2.5
# 10 ep.mean score : 4.1
# Target net updated!
# 10 ep.mean score : 4.3
# 10 ep.mean score : 3.9
# 10 ep.mean score : 3.7
# 10 ep.mean score : 4.0
# Target net updated!
# 10 ep.mean score : 3.5
# 10 ep.mean score : 3.3
# 10 ep.mean score : 4.4
# 10 ep.mean score : 3.4
# Target net updated!
#
# eps_threshold: 0.5639996339496421
# steps_done:  662512
# Mean score : 3.88
# 10 ep.mean score : 4.2
# 10 ep.mean score : 3.9
# 10 ep.mean score : 3.9
# Target net updated!
# 10 ep.mean score : 3.3
# 10 ep.mean score : 4.6
# 10 ep.mean score : 4.5
# 10 ep.mean score : 5.3
# Target net updated!
# 10 ep.mean score : 4.2
# 10 ep.mean score : 2.6
# 10 ep.mean score : 3.9
#
# eps_threshold: 0.5516189364586499
# steps_done:  689557
# Mean score : 4.12
# 10 ep.mean score : 5.0
# Target net updated!
# 10 ep.mean score : 3.8
# 10 ep.mean score : 4.4
# 10 ep.mean score : 3.9
# 10 ep.mean score : 3.6
# Target net updated!
# 10 ep.mean score : 4.0
# 10 ep.mean score : 3.4
# 10 ep.mean score : 4.3
# Target net updated!
# 10 ep.mean score : 4.2
# 10 ep.mean score : 3.5
#
# eps_threshold: 0.5398099770657308
# steps_done:  716053
# Mean score : 3.99
# 10 ep.mean score : 4.8
# 10 ep.mean score : 4.0
# Target net updated!
# 10 ep.mean score : 4.3
# 10 ep.mean score : 4.0
# 10 ep.mean score : 2.9
# 10 ep.mean score : 4.1
# Target net updated!
# 10 ep.mean score : 3.8
# 10 ep.mean score : 5.2
# 10 ep.mean score : 5.1
# Target net updated!
# 10 ep.mean score : 4.0
#
# eps_threshold: 0.5280143672349324
# steps_done:  743239
# Mean score : 4.14
# 10 ep.mean score : 4.0
# 10 ep.mean score : 3.8
# 10 ep.mean score : 4.0
# Target net updated!
# 10 ep.mean score : 4.8
# 10 ep.mean score : 4.1
# 10 ep.mean score : 3.5
# 10 ep.mean score : 3.6
# Target net updated!
# 10 ep.mean score : 3.8
# 10 ep.mean score : 5.2
# 10 ep.mean score : 4.9
# Target net updated!
#
# eps_threshold: 0.5164355731487927
# steps_done:  770664
# Mean score : 4.14
# 10 ep.mean score : 3.7
# 10 ep.mean score : 4.9
# 10 ep.mean score : 4.3
# 10 ep.mean score : 3.8
# Target net updated!
# 10 ep.mean score : 3.7
# 10 ep.mean score : 4.2
# 10 ep.mean score : 3.5
# 10 ep.mean score : 4.0
# Target net updated!
# 10 ep.mean score : 4.9
# 10 ep.mean score : 4.1
#
# eps_threshold: 0.5050922274677219
# steps_done:  798281
# Mean score : 4.16
# 10 ep.mean score : 4.2
# Target net updated!
# 10 ep.mean score : 5.3
# 10 ep.mean score : 6.0
# 10 ep.mean score : 3.2
# 10 ep.mean score : 4.2
# Target net updated!
# 10 ep.mean score : 5.1
# 10 ep.mean score : 6.2
# 10 ep.mean score : 4.5
# Target net updated!
# 10 ep.mean score : 4.2
# 10 ep.mean score : 5.1
#
# eps_threshold: 0.4936065330845676
# steps_done:  827044
# Mean score : 4.88
# 10 ep.mean score : 5.0
# 10 ep.mean score : 4.5
# Target net updated!
# 10 ep.mean score : 5.9
# 10 ep.mean score : 4.3
# 10 ep.mean score : 3.6
# Target net updated!
# 10 ep.mean score : 4.1
# 10 ep.mean score : 4.9
# 10 ep.mean score : 5.5
# Target net updated!
# 10 ep.mean score : 5.4
# 10 ep.mean score : 5.0
#
# eps_threshold: 0.4822511156040399
# steps_done:  856318
# Mean score : 4.7
# 10 ep.mean score : 3.8
# 10 ep.mean score : 4.3
# Target net updated!
# 10 ep.mean score : 3.0
# 10 ep.mean score : 3.7
# 10 ep.mean score : 6.4
# Target net updated!
# 10 ep.mean score : 4.6
# 10 ep.mean score : 5.0
# 10 ep.mean score : 5.0
# 10 ep.mean score : 4.4
# Target net updated!
# 10 ep.mean score : 4.8
#
# eps_threshold: 0.4715683248226
# steps_done:  884663
# Mean score : 4.62
# 10 ep.mean score : 5.0
# 10 ep.mean score : 5.8
# Target net updated!
# 10 ep.mean score : 4.6
# 10 ep.mean score : 5.8
# 10 ep.mean score : 5.3
# Target net updated!
# 10 ep.mean score : 5.7
# 10 ep.mean score : 4.6
# 10 ep.mean score : 7.9
# 10 ep.mean score : 5.7
# Target net updated!
# 10 ep.mean score : 5.4
#
# eps_threshold: 0.45991891260824114
# steps_done:  916517
# Mean score : 5.65
# 10 ep.mean score : 5.7
# 10 ep.mean score : 5.8
# Target net updated!
# 10 ep.mean score : 6.7
# 10 ep.mean score : 3.8
# 10 ep.mean score : 4.8
# Target net updated!
# 10 ep.mean score : 5.4
# 10 ep.mean score : 4.7
# 10 ep.mean score : 6.4
# Target net updated!
# 10 ep.mean score : 5.8
# 10 ep.mean score : 6.2
#
# eps_threshold: 0.4487410826423295
# steps_done:  948066
# Mean score : 5.62
# 10 ep.mean score : 6.6
# Target net updated!
# 10 ep.mean score : 4.9
# 10 ep.mean score : 5.7
# 10 ep.mean score : 6.2
# Target net updated!
# 10 ep.mean score : 5.1
# 10 ep.mean score : 6.5
# 10 ep.mean score : 6.3
# Target net updated!
# 10 ep.mean score : 7.2
# 10 ep.mean score : 7.7
# 10 ep.mean score : 4.8
# Target net updated!
#
# eps_threshold: 0.43715129066112557
# steps_done:  981864
# Mean score : 6.01
# 10 ep.mean score : 5.7
# 10 ep.mean score : 6.7
# 10 ep.mean score : 5.2
# Target net updated!
# 10 ep.mean score : 5.3
# 10 ep.mean score : 6.2
# 10 ep.mean score : 6.7
# Target net updated!
# 10 ep.mean score : 5.6
# 10 ep.mean score : 7.8
# 10 ep.mean score : 8.1
# Target net updated!
# 10 ep.mean score : 6.4
#
# eps_threshold: 0.4258378168741501
# steps_done:  1015996
# Mean score : 6.34
# 10 ep.mean score : 5.4
# 10 ep.mean score : 4.7
# Target net updated!
# 10 ep.mean score : 5.6
# 10 ep.mean score : 6.3
# 10 ep.mean score : 6.5
# Target net updated!
# 10 ep.mean score : 6.1
# 10 ep.mean score : 6.9
# Target net updated!
# 10 ep.mean score : 8.2
# 10 ep.mean score : 6.6
# 10 ep.mean score : 5.9
# Target net updated!
#
# eps_threshold: 0.4148334482635322
# steps_done:  1050352
# Mean score : 6.37
# 10 ep.mean score : 6.9
# 10 ep.mean score : 6.0
# 10 ep.mean score : 6.1
# Target net updated!
# 10 ep.mean score : 6.7
# 10 ep.mean score : 8.3
# 10 ep.mean score : 5.8
# Target net updated!
# 10 ep.mean score : 7.9
# 10 ep.mean score : 5.8
# 10 ep.mean score : 6.3
# Target net updated!
# 10 ep.mean score : 6.8
#
# eps_threshold: 0.4039605013893416
# steps_done:  1085498
# Mean score : 6.57
# 10 ep.mean score : 6.0
# 10 ep.mean score : 7.4
# Target net updated!
# 10 ep.mean score : 6.5
# 10 ep.mean score : 6.3
# Target net updated!
# 10 ep.mean score : 9.3
# 10 ep.mean score : 6.3
# 10 ep.mean score : 6.8
# Target net updated!
# 10 ep.mean score : 8.4
# 10 ep.mean score : 8.1
# 10 ep.mean score : 6.8
# Target net updated!
#
# eps_threshold: 0.39295961399560464
# steps_done:  1122361
# Mean score : 7.38
# 10 ep.mean score : 7.9
# 10 ep.mean score : 7.3
# 10 ep.mean score : 7.5
# Target net updated!
# 10 ep.mean score : 7.3
# 10 ep.mean score : 7.7
# Target net updated!
# 10 ep.mean score : 7.1
# 10 ep.mean score : 7.4
# 10 ep.mean score : 5.7
# Target net updated!
# 10 ep.mean score : 8.2
# 10 ep.mean score : 6.5
#
# eps_threshold: 0.382668197650159
# steps_done:  1158122
# Mean score : 7.3
# 10 ep.mean score : 8.3
# Target net updated!
# 10 ep.mean score : 7.0
# 10 ep.mean score : 7.1
# 10 ep.mean score : 7.0
# Target net updated!
# 10 ep.mean score : 6.9
# 10 ep.mean score : 7.5
# Target net updated!
# 10 ep.mean score : 8.8
# 10 ep.mean score : 8.4
# 10 ep.mean score : 7.9
# Target net updated!
# 10 ep.mean score : 9.0
#
# eps_threshold: 0.3721969168371718
# steps_done:  1195870
# Mean score : 7.79
# 10 ep.mean score : 8.3
# 10 ep.mean score : 7.1
# Target net updated!
# 10 ep.mean score : 7.3
# 10 ep.mean score : 10.1
# Target net updated!
# 10 ep.mean score : 6.5
# 10 ep.mean score : 9.8
# 10 ep.mean score : 7.6
# Target net updated!
# 10 ep.mean score : 8.7
# 10 ep.mean score : 7.9
# Target net updated!
# 10 ep.mean score : 9.3
#
# eps_threshold: 0.36169763261708265
# steps_done:  1235206
# Mean score : 8.23
# 10 ep.mean score : 8.0
# 10 ep.mean score : 7.4
# Target net updated!
# 10 ep.mean score : 9.4
# 10 ep.mean score : 9.0
# Target net updated!
# 10 ep.mean score : 7.3
# 10 ep.mean score : 9.8
# 10 ep.mean score : 6.7
# Target net updated!
# 10 ep.mean score : 9.3
# 10 ep.mean score : 6.9
# Target net updated!
# 10 ep.mean score : 7.6
#
# eps_threshold: 0.35161716939190324
# steps_done:  1274487
# Mean score : 8.26
# 10 ep.mean score : 9.2
# 10 ep.mean score : 7.0
# Target net updated!
# 10 ep.mean score : 7.3
# 10 ep.mean score : 10.3
# Target net updated!
# 10 ep.mean score : 8.9
# 10 ep.mean score : 8.2
# 10 ep.mean score : 8.9
# Target net updated!
# 10 ep.mean score : 6.6
# 10 ep.mean score : 7.2
# Target net updated!
# 10 ep.mean score : 8.4
#
# eps_threshold: 0.341919920247007
# steps_done:  1313789
# Mean score : 7.94
# 10 ep.mean score : 6.6
# 10 ep.mean score : 9.2
# Target net updated!
# 10 ep.mean score : 9.3
# 10 ep.mean score : 7.6
# 10 ep.mean score : 8.2
# Target net updated!
# 10 ep.mean score : 7.8
# 10 ep.mean score : 7.8
# Target net updated!
# 10 ep.mean score : 9.4
# 10 ep.mean score : 7.9
# Target net updated!
# 10 ep.mean score : 10.1
#
# eps_threshold: 0.33229631192946496
# steps_done:  1354382
# Mean score : 8.51
# 10 ep.mean score : 7.8
# 10 ep.mean score : 9.2
# Target net updated!
# 10 ep.mean score : 7.3
# 10 ep.mean score : 9.1
# Target net updated!
# 10 ep.mean score : 8.2
# 10 ep.mean score : 9.3
# 10 ep.mean score : 8.2
# Target net updated!
# 10 ep.mean score : 7.9
# 10 ep.mean score : 9.1
# Target net updated!
# 10 ep.mean score : 9.6
#
# eps_threshold: 0.32279493253204866
# steps_done:  1396144
# Mean score : 8.56
# 10 ep.mean score : 7.7
# Target net updated!
# 10 ep.mean score : 7.9
# 10 ep.mean score : 8.3
# 10 ep.mean score : 10.0
# Target net updated!
# 10 ep.mean score : 9.7
# 10 ep.mean score : 10.0
# Target net updated!
# 10 ep.mean score : 11.6
# 10 ep.mean score : 12.6
# Target net updated!
# 10 ep.mean score : 9.6
# 10 ep.mean score : 10.2
# Target net updated!
#
# eps_threshold: 0.31321600574493125
# steps_done:  1440090
# Mean score : 9.87
# 10 ep.mean score : 8.8
# 10 ep.mean score : 10.7
# 10 ep.mean score : 9.4
# Target net updated!
# 10 ep.mean score : 12.0
# 10 ep.mean score : 10.8
# Target net updated!
# 10 ep.mean score : 11.0
# 10 ep.mean score : 10.3
# Target net updated!
# 10 ep.mean score : 10.8
# 10 ep.mean score : 11.4
# Target net updated!
# 10 ep.mean score : 10.1
#
# eps_threshold: 0.30331586669801086
# steps_done:  1487635
# Mean score : 10.69
# 10 ep.mean score : 10.4
# Target net updated!
# 10 ep.mean score : 8.8
# 10 ep.mean score : 10.0
# Target net updated!
# 10 ep.mean score : 9.6
# 10 ep.mean score : 8.9
# 10 ep.mean score : 10.1
# Target net updated!
# 10 ep.mean score : 9.1
# 10 ep.mean score : 8.7
# Target net updated!
# 10 ep.mean score : 9.0
# 10 ep.mean score : 10.8
# Target net updated!
#
# eps_threshold: 0.2943770371366391
# steps_done:  1532596
# Mean score : 9.87
# 10 ep.mean score : 13.7
# 10 ep.mean score : 9.7
# Target net updated!
# 10 ep.mean score : 10.4
# 10 ep.mean score : 12.8
# Target net updated!
# 10 ep.mean score : 11.8
# 10 ep.mean score : 12.9
# Target net updated!
# 10 ep.mean score : 12.8
# 10 ep.mean score : 13.7
# Target net updated!
# 10 ep.mean score : 13.5
# 10 ep.mean score : 10.5
# Target net updated!
#
# eps_threshold: 0.2847280536494866
# steps_done:  1583511
# Mean score : 11.96
# 10 ep.mean score : 11.5
# 10 ep.mean score : 11.2
# Target net updated!
# 10 ep.mean score : 10.7
# 10 ep.mean score : 9.9
# Target net updated!
# 10 ep.mean score : 13.1
# 10 ep.mean score : 11.1
# Target net updated!
# 10 ep.mean score : 10.6
# 10 ep.mean score : 13.4
# Target net updated!
# 10 ep.mean score : 12.5
# 10 ep.mean score : 10.9
# Target net updated!
#
# eps_threshold: 0.2757830849990846
# steps_done:  1633145
# Mean score : 11.43
# 10 ep.mean score : 10.9
# 10 ep.mean score : 10.3
# Target net updated!
# 10 ep.mean score : 13.2
# 10 ep.mean score : 9.1
# Target net updated!
# 10 ep.mean score : 10.2
# 10 ep.mean score : 11.4
# Target net updated!
# 10 ep.mean score : 12.6
# 10 ep.mean score : 12.5
# Target net updated!
# 10 ep.mean score : 14.5
# 10 ep.mean score : 10.8
# Target net updated!
#
# eps_threshold: 0.2672655657311423
# steps_done:  1682813
# Mean score : 11.65
# 10 ep.mean score : 11.9
# 10 ep.mean score : 11.0
# Target net updated!
# 10 ep.mean score : 14.1
# 10 ep.mean score : 15.1
# Target net updated!
# 10 ep.mean score : 13.4
# Target net updated!
# 10 ep.mean score : 12.0
# 10 ep.mean score : 12.9
# Target net updated!
# 10 ep.mean score : 14.7
# 10 ep.mean score : 14.1
# Target net updated!
# 10 ep.mean score : 14.0
#
# eps_threshold: 0.2584071731391401
# steps_done:  1737227
# Mean score : 13.49
# 10 ep.mean score : 13.6
# Target net updated!
# 10 ep.mean score : 12.7
# 10 ep.mean score : 12.3
# Target net updated!
# 10 ep.mean score : 13.4
# 10 ep.mean score : 11.3
# Target net updated!
# 10 ep.mean score : 12.8
# 10 ep.mean score : 12.4
# Target net updated!
# 10 ep.mean score : 13.9
# Target net updated!
# 10 ep.mean score : 16.0
# 10 ep.mean score : 13.9
# Target net updated!
#
# eps_threshold: 0.24997277285556532
# steps_done:  1791942
# Mean score : 13.25
# 10 ep.mean score : 13.8
# 10 ep.mean score : 15.9
# Target net updated!
# 10 ep.mean score : 14.1
# 10 ep.mean score : 13.3
# Target net updated!
# 10 ep.mean score : 16.8
# Target net updated!
# 10 ep.mean score : 11.9
# 10 ep.mean score : 15.9
# Target net updated!
# 10 ep.mean score : 13.9
# 10 ep.mean score : 14.7
# Target net updated!
# 10 ep.mean score : 18.3
#
# eps_threshold: 0.24159739204437694
# steps_done:  1849408
# Mean score : 15.1
# 10 ep.mean score : 16.2
# Target net updated!
# 10 ep.mean score : 14.7
# Target net updated!
# 10 ep.mean score : 16.7
# 10 ep.mean score : 12.3
# Target net updated!
# 10 ep.mean score : 13.0
# 10 ep.mean score : 16.0
# Target net updated!
# 10 ep.mean score : 14.8
# 10 ep.mean score : 15.9
# Target net updated!
# 10 ep.mean score : 12.4
# 10 ep.mean score : 14.2
# Target net updated!
#
# eps_threshold: 0.2338317967488711
# steps_done:  1905812
# Mean score : 14.48
# 10 ep.mean score : 14.8
# Target net updated!
# 10 ep.mean score : 16.8
# 10 ep.mean score : 16.5
# Target net updated!
# 10 ep.mean score : 14.6
# 10 ep.mean score : 13.2
# Target net updated!
# 10 ep.mean score : 14.3
# Target net updated!
# 10 ep.mean score : 14.3
# 10 ep.mean score : 16.4
# Target net updated!
# 10 ep.mean score : 16.1
# 10 ep.mean score : 15.7
# Target net updated!
#
# eps_threshold: 0.22630047160102187
# steps_done:  1963732
# Mean score : 15.12
# 10 ep.mean score : 13.3
# 10 ep.mean score : 14.0
# Target net updated!
# 10 ep.mean score : 16.6
# Target net updated!
# 10 ep.mean score : 18.7
# 10 ep.mean score : 13.8
# Target net updated!
# 10 ep.mean score : 18.7
# Target net updated!
# 10 ep.mean score : 18.2
# 10 ep.mean score : 13.4
# Target net updated!
# 10 ep.mean score : 16.7
# 10 ep.mean score : 14.7
# Target net updated!
#
# eps_threshold: 0.21886908521943835
# steps_done:  2024373
# Mean score : 16.14
# 10 ep.mean score : 16.6
# 10 ep.mean score : 13.4
# Target net updated!
# 10 ep.mean score : 15.1
# Target net updated!
# 10 ep.mean score : 15.3
# 10 ep.mean score : 15.8
# Target net updated!
# 10 ep.mean score : 17.6
# Target net updated!
# 10 ep.mean score : 16.6
# 10 ep.mean score : 19.2
# Target net updated!
# 10 ep.mean score : 15.0
# Target net updated!
# 10 ep.mean score : 16.3
#
# eps_threshold: 0.21168425780413097
# steps_done:  2086720
# Mean score : 16.18
# 10 ep.mean score : 17.5
# Target net updated!
# 10 ep.mean score : 18.8
# 10 ep.mean score : 18.5
# Target net updated!
# 10 ep.mean score : 14.6
# Target net updated!
# 10 ep.mean score : 19.1
# 10 ep.mean score : 18.5
# Target net updated!
# 10 ep.mean score : 18.0
# Target net updated!
# 10 ep.mean score : 17.6
# 10 ep.mean score : 20.3
# Target net updated!
# 10 ep.mean score : 18.4
# Target net updated!
#
# eps_threshold: 0.20453059078220098
# steps_done:  2152916
# Mean score : 18.03
# 10 ep.mean score : 16.5
# 10 ep.mean score : 15.7
# Target net updated!
# 10 ep.mean score : 19.4
# Target net updated!
# 10 ep.mean score : 16.5
# 10 ep.mean score : 16.5
# Target net updated!
# 10 ep.mean score : 15.2
# Target net updated!
# 10 ep.mean score : 17.9
# 10 ep.mean score : 16.1
# Target net updated!
# 10 ep.mean score : 19.0
# 10 ep.mean score : 19.7
# Target net updated!
#
# eps_threshold: 0.19818453942723535
# steps_done:  2215547
# Mean score : 17.48
# 10 ep.mean score : 18.8
# Target net updated!
# 10 ep.mean score : 20.5
# 10 ep.mean score : 18.8
# Target net updated!
# 10 ep.mean score : 17.0
# Target net updated!
# 10 ep.mean score : 20.0
# 10 ep.mean score : 19.8
# Target net updated!
# 10 ep.mean score : 19.4
# Target net updated!
# 10 ep.mean score : 16.7
# 10 ep.mean score : 22.4
# Target net updated!
# 10 ep.mean score : 21.9
# Target net updated!
#
# eps_threshold: 0.19163687565518484
# steps_done:  2284562
# Mean score : 19.89
# 10 ep.mean score : 22.4
# Target net updated!
# 10 ep.mean score : 21.4
# 10 ep.mean score : 20.4
# Target net updated!
# 10 ep.mean score : 22.6
# Target net updated!
# 10 ep.mean score : 19.8
# 10 ep.mean score : 18.4
# Target net updated!
# 10 ep.mean score : 19.3
# Target net updated!
# 10 ep.mean score : 18.4
# 10 ep.mean score : 17.8
# Target net updated!
# 10 ep.mean score : 17.3
# Target net updated!
#
# eps_threshold: 0.18558976971449134
# steps_done:  2352830
# Mean score : 19.85
# 10 ep.mean score : 23.1
# 10 ep.mean score : 19.5
# Target net updated!
# 10 ep.mean score : 24.6
# Target net updated!
# 10 ep.mean score : 23.7
# Target net updated!
# 10 ep.mean score : 22.9
# Target net updated!
# 10 ep.mean score : 23.9
# 10 ep.mean score : 16.6
# Target net updated!
# 10 ep.mean score : 19.9
# Target net updated!
# 10 ep.mean score : 24.0
# 10 ep.mean score : 17.4
# Target net updated!
#
# eps_threshold: 0.17955445560417277
# steps_done:  2425954
# Mean score : 21.4
# 10 ep.mean score : 21.5
# Target net updated!
# 10 ep.mean score : 20.3
# Target net updated!
# 10 ep.mean score : 19.6
# 10 ep.mean score : 20.0
# Target net updated!
# 10 ep.mean score : 17.7
# Target net updated!
# 10 ep.mean score : 22.9
# 10 ep.mean score : 23.5
# Target net updated!
# 10 ep.mean score : 26.2
# Target net updated!
# 10 ep.mean score : 20.2
# Target net updated!
# 10 ep.mean score : 22.2
#
# eps_threshold: 0.17396350259226157
# steps_done:  2498824
# Mean score : 21.21
# 10 ep.mean score : 19.5
# Target net updated!
# 10 ep.mean score : 22.3
# Target net updated!
# 10 ep.mean score : 22.4
# Target net updated!
# 10 ep.mean score : 18.0
# 10 ep.mean score : 27.7
# Target net updated!
# 10 ep.mean score : 26.4
# Target net updated!
# 10 ep.mean score : 23.1
# Target net updated!
# 10 ep.mean score : 20.6
# 10 ep.mean score : 24.9
# Target net updated!
# 10 ep.mean score : 22.3
# Target net updated!
#
# eps_threshold: 0.16862855922461417
# steps_done:  2573687
# Mean score : 22.91
# 10 ep.mean score : 21.4
# Target net updated!
# 10 ep.mean score : 23.5
# 10 ep.mean score : 21.4
# Target net updated!
# 10 ep.mean score : 25.1
# Target net updated!
# 10 ep.mean score : 20.7
# Target net updated!
# 10 ep.mean score : 20.4
# 10 ep.mean score : 28.3
# Target net updated!
# 10 ep.mean score : 21.3
# Target net updated!
# 10 ep.mean score : 24.4
# Target net updated!
# 10 ep.mean score : 24.6
#
# eps_threshold: 0.16358774501426454
# steps_done:  2649975
# Mean score : 23.45
# 10 ep.mean score : 24.8
# Target net updated!
# 10 ep.mean score : 21.3
# Target net updated!
# 10 ep.mean score : 29.2
# Target net updated!
# 10 ep.mean score : 24.5
# Target net updated!
# 10 ep.mean score : 28.9
# Target net updated!
# 10 ep.mean score : 25.5
# 10 ep.mean score : 27.1
# Target net updated!
# 10 ep.mean score : 23.1
# Target net updated!
# 10 ep.mean score : 25.2
# Target net updated!
# 10 ep.mean score : 25.2
# Target net updated!
#
# eps_threshold: 0.15869413243525432
# steps_done:  2730056
# Mean score : 25.15
# 10 ep.mean score : 21.5
# 10 ep.mean score : 26.2
# Target net updated!
# 10 ep.mean score : 25.1
# Target net updated!
# 10 ep.mean score : 24.7
# Target net updated!
# 10 ep.mean score : 27.4
# Target net updated!
# 10 ep.mean score : 29.8
# Target net updated!
# 10 ep.mean score : 30.2
# 10 ep.mean score : 23.9
# Target net updated!
# 10 ep.mean score : 26.0
# Target net updated!
# 10 ep.mean score : 26.6
# Target net updated!
#
# eps_threshold: 0.15398330128749105
# steps_done:  2813721
# Mean score : 27.0
# 10 ep.mean score : 30.1
# Target net updated!
# 10 ep.mean score : 24.4
# 10 ep.mean score : 25.5
# Target net updated!
# 10 ep.mean score : 28.3
# Target net updated!
# 10 ep.mean score : 26.9
# Target net updated!
# 10 ep.mean score : 26.6
# Target net updated!
# 10 ep.mean score : 25.1
# Target net updated!
# 10 ep.mean score : 25.6
# 10 ep.mean score : 26.0
# Target net updated!
# 10 ep.mean score : 30.0
# Target net updated!
#
# eps_threshold: 0.14972977077495012
# steps_done:  2895792
# Mean score : 26.83
# 10 ep.mean score : 29.9
# Target net updated!
# 10 ep.mean score : 25.2
# Target net updated!
# 10 ep.mean score : 25.7
# 10 ep.mean score : 22.5
# Target net updated!
# 10 ep.mean score : 25.7
# Target net updated!
# 10 ep.mean score : 27.1
# Target net updated!
# 10 ep.mean score : 23.0
# Target net updated!
# 10 ep.mean score : 23.4
# 10 ep.mean score : 27.0
# Target net updated!
# 10 ep.mean score : 31.3
# Target net updated!
#
# eps_threshold: 0.14586011400326587
# steps_done:  2976800
# Mean score : 26.1
# 10 ep.mean score : 30.1
# Target net updated!
# 10 ep.mean score : 27.7
# Target net updated!
# 10 ep.mean score : 28.9
# Target net updated!
# 10 ep.mean score : 25.4
# Target net updated!
# 10 ep.mean score : 29.2
# 10 ep.mean score : 24.5
# Target net updated!
# 10 ep.mean score : 27.7
# Target net updated!
# 10 ep.mean score : 29.7
# Target net updated!
# 10 ep.mean score : 30.2
# 10 ep.mean score : 24.4
# Target net updated!
#
# eps_threshold: 0.14225377772114725
# steps_done:  3058702
# Mean score : 28.2
# 10 ep.mean score : 34.3
# Target net updated!
# 10 ep.mean score : 29.3
# Target net updated!
# 10 ep.mean score : 29.9
# Target net updated!
# 10 ep.mean score : 28.9
# Target net updated!
# 10 ep.mean score : 25.9
# Target net updated!
# 10 ep.mean score : 30.3
# Target net updated!
# 10 ep.mean score : 29.9
# 10 ep.mean score : 35.2
# Target net updated!
# 10 ep.mean score : 29.5
# Target net updated!
# 10 ep.mean score : 32.0
# Target net updated!
#
# eps_threshold: 0.13870859867438737
# steps_done:  3146334
# Mean score : 30.18
# 10 ep.mean score : 30.9
# Target net updated!
# 10 ep.mean score : 35.1
# Target net updated!
# 10 ep.mean score : 34.6
# Target net updated!
# 10 ep.mean score : 29.9
# Target net updated!
# 10 ep.mean score : 31.0
# Target net updated!
# 10 ep.mean score : 29.9
# Target net updated!
# 10 ep.mean score : 30.1
# 10 ep.mean score : 29.6
# Target net updated!
# 10 ep.mean score : 30.6
# Target net updated!
# 10 ep.mean score : 30.2
# Target net updated!
#
# eps_threshold: 0.13540077679725687
# steps_done:  3235662
# Mean score : 31.59
# 10 ep.mean score : 34.9
# Target net updated!
# 10 ep.mean score : 30.0
# Target net updated!
# 10 ep.mean score : 31.5
# Target net updated!
# 10 ep.mean score : 36.5
# Target net updated!
# 10 ep.mean score : 32.0
# Target net updated!
# 10 ep.mean score : 29.5
# 10 ep.mean score : 31.1
# Target net updated!
# 10 ep.mean score : 29.7
# Target net updated!
# 10 ep.mean score : 33.7
# Target net updated!
# 10 ep.mean score : 35.4
# Target net updated!
#
# eps_threshold: 0.13237834267453813
# steps_done:  3324906
# Mean score : 31.83
# 10 ep.mean score : 28.9
# Target net updated!
# 10 ep.mean score : 31.6
# Target net updated!
# 10 ep.mean score : 36.3
# Target net updated!
# 10 ep.mean score : 34.9
# Target net updated!
# 10 ep.mean score : 34.9
# Target net updated!
# 10 ep.mean score : 31.6
# Target net updated!
# 10 ep.mean score : 40.6
# 10 ep.mean score : 31.7
# Target net updated!
# 10 ep.mean score : 33.7
# Target net updated!
# 10 ep.mean score : 36.6
# Target net updated!
#
# eps_threshold: 0.12947215040340945
# steps_done:  3418950
# Mean score : 35.01
# 10 ep.mean score : 38.2
# Target net updated!
# 10 ep.mean score : 34.3
# Target net updated!
# 10 ep.mean score : 32.7
# Target net updated!
# 10 ep.mean score : 32.0
# Target net updated!
# 10 ep.mean score : 34.7
# Target net updated!
# 10 ep.mean score : 36.9
# Target net updated!
# 10 ep.mean score : 31.7
# Target net updated!
# 10 ep.mean score : 36.1
# Target net updated!
# 10 ep.mean score : 33.0
# Target net updated!
# 10 ep.mean score : 35.0
# Target net updated!
#
# eps_threshold: 0.12683722089465604
# steps_done:  3512606
# Mean score : 34.06
# 10 ep.mean score : 34.2
# Target net updated!
# 10 ep.mean score : 35.9
# Target net updated!
# 10 ep.mean score : 30.0
# Target net updated!
# 10 ep.mean score : 31.2
# 10 ep.mean score : 30.4
# Target net updated!
# 10 ep.mean score : 31.7
# Target net updated!
# 10 ep.mean score : 28.9
# Target net updated!
# 10 ep.mean score : 30.6
# Target net updated!
# 10 ep.mean score : 36.7
# Target net updated!
# 10 ep.mean score : 37.2
# Target net updated!
#
# eps_threshold: 0.12443505455369548
# steps_done:  3606377
# Mean score : 33.34
# 10 ep.mean score : 40.8
# Target net updated!
# 10 ep.mean score : 36.1
# Target net updated!
# 10 ep.mean score : 35.9
# Target net updated!
# 10 ep.mean score : 28.9
# Target net updated!
# 10 ep.mean score : 32.6
# Target net updated!
# 10 ep.mean score : 35.2
# Target net updated!
# 10 ep.mean score : 35.0
# Target net updated!
# 10 ep.mean score : 40.0
# Target net updated!
# 10 ep.mean score : 29.8
# Target net updated!
# 10 ep.mean score : 32.7
#
# eps_threshold: 0.12225747179661864
# steps_done:  3699718
# Mean score : 33.95
# 10 ep.mean score : 33.3
# Target net updated!
# 10 ep.mean score : 35.4
# Target net updated!
# 10 ep.mean score : 38.8
# Target net updated!
# 10 ep.mean score : 32.9
# Target net updated!
# 10 ep.mean score : 36.8
# Target net updated!
# 10 ep.mean score : 31.4
# Target net updated!
# 10 ep.mean score : 39.3
# Target net updated!
# 10 ep.mean score : 31.8
# Target net updated!
# 10 ep.mean score : 36.1
# Target net updated!
# 10 ep.mean score : 36.8
# Target net updated!
#
# eps_threshold: 0.12019537793900537
# steps_done:  3796942
# Mean score : 36.19
# 10 ep.mean score : 42.6
# Target net updated!
# 10 ep.mean score : 38.4
# Target net updated!
# 10 ep.mean score : 33.9
# Target net updated!
# 10 ep.mean score : 39.7
# Target net updated!
# 10 ep.mean score : 34.1
# Target net updated!
# 10 ep.mean score : 42.4
# Target net updated!
# 10 ep.mean score : 37.5
# Target net updated!
# 10 ep.mean score : 40.7
# Target net updated!
# 10 ep.mean score : 39.4
# Target net updated!
# 10 ep.mean score : 32.4
# Target net updated!
#
# eps_threshold: 0.11825547003974737
# steps_done:  3897931
# Mean score : 37.34
# 10 ep.mean score : 34.9
# Target net updated!
# 10 ep.mean score : 32.5
# Target net updated!
# 10 ep.mean score : 32.1
# Target net updated!
# 10 ep.mean score : 40.8
# Target net updated!
# 10 ep.mean score : 38.5
# Target net updated!
# 10 ep.mean score : 39.9
# Target net updated!
# 10 ep.mean score : 44.7
# Target net updated!
# 10 ep.mean score : 42.9
# Target net updated!
# 10 ep.mean score : 35.3
# Target net updated!
# 10 ep.mean score : 39.4
# Target net updated!
#
# eps_threshold: 0.1165275017039641
# steps_done:  3997370
# Mean score : 38.5
# 10 ep.mean score : 38.9
# Target net updated!
# 10 ep.mean score : 35.9
# Target net updated!
# 10 ep.mean score : 37.6
# Target net updated!
# 10 ep.mean score : 32.6
# Target net updated!
# 10 ep.mean score : 31.3
# Target net updated!
# 10 ep.mean score : 34.9
# Target net updated!
# 10 ep.mean score : 44.2
# Target net updated!
# 10 ep.mean score : 38.5
# Target net updated!
# 10 ep.mean score : 34.2
# Target net updated!
# 10 ep.mean score : 39.4
# Target net updated!
#
# eps_threshold: 0.11499837352151897
# steps_done:  4094454
# Mean score : 36.15
# 10 ep.mean score : 32.9
# Target net updated!
# 10 ep.mean score : 39.5
# Target net updated!
# 10 ep.mean score : 37.8
# Target net updated!
# 10 ep.mean score : 38.5
# Target net updated!
# 10 ep.mean score : 33.9
# Target net updated!
# 10 ep.mean score : 42.3
# Target net updated!
# 10 ep.mean score : 43.7
# Target net updated!
# 10 ep.mean score : 39.1
# Target net updated!
# 10 ep.mean score : 40.9
# Target net updated!
# 10 ep.mean score : 40.5
# Target net updated!
#
# eps_threshold: 0.1135565491589828
# steps_done:  4195526
# Mean score : 39.6
# 10 ep.mean score : 39.8
# Target net updated!
# 10 ep.mean score : 42.0
# Target net updated!
# 10 ep.mean score : 38.5
# Target net updated!
# 10 ep.mean score : 44.1
# Target net updated!
# 10 ep.mean score : 33.6
# Target net updated!
# 10 ep.mean score : 45.2
# Target net updated!
# 10 ep.mean score : 39.6
# Target net updated!
# 10 ep.mean score : 42.5
# Target net updated!
# 10 ep.mean score : 40.3
# Target net updated!
# 10 ep.mean score : 41.2
# Target net updated!
#
# eps_threshold: 0.11221776161810945
# steps_done:  4299505
# Mean score : 40.51
# 10 ep.mean score : 38.1
# Target net updated!
# 10 ep.mean score : 38.6
# Target net updated!
# 10 ep.mean score : 33.1
# Target net updated!
# 10 ep.mean score : 38.4
# Target net updated!
# 10 ep.mean score : 47.1
# Target net updated!
# 10 ep.mean score : 38.7
# Target net updated!
# Target net updated!
# 10 ep.mean score : 41.3
# Target net updated!
# 10 ep.mean score : 45.8
# Target net updated!
# 10 ep.mean score : 45.8
# Target net updated!
# 10 ep.mean score : 41.2
# Target net updated!
#
# eps_threshold: 0.11100726779567624
# steps_done:  4403840
# Mean score : 41.63
# 10 ep.mean score : 46.3
# Target net updated!
# 10 ep.mean score : 43.9
# Target net updated!
# 10 ep.mean score : 44.2
# Target net updated!
# 10 ep.mean score : 38.3
# Target net updated!
# 10 ep.mean score : 34.9
# Target net updated!
# 10 ep.mean score : 46.1
# Target net updated!
# 10 ep.mean score : 46.0
# Target net updated!
# 10 ep.mean score : 45.3
# Target net updated!
# 10 ep.mean score : 41.3
# Target net updated!
# 10 ep.mean score : 41.4
# Target net updated!
#
# eps_threshold: 0.1099020297692698
# steps_done:  4509656
# Mean score : 42.37
# 10 ep.mean score : 42.3
# Target net updated!
# Target net updated!
# 10 ep.mean score : 43.3
# 10 ep.mean score : 40.3
# Target net updated!
# 10 ep.mean score : 40.5
# Target net updated!
# Target net updated!
# 10 ep.mean score : 39.2
# Target net updated!
# 10 ep.mean score : 39.8
# Target net updated!
# 10 ep.mean score : 40.9
# 10 ep.mean score : 28.8
# Target net updated!
# Target net updated!
# 10 ep.mean score : 48.9
# Target net updated!
# 10 ep.mean score : 38.7
# Target net updated!
#
# eps_threshold: 0.10894505408488617
# steps_done:  4611295
# Mean score : 39.83
# 10 ep.mean score : 37.9
# Target net updated!
# 10 ep.mean score : 38.5
# Target net updated!
# 10 ep.mean score : 39.1
# 10 ep.mean score : 34.4
# Target net updated!
# Target net updated!
# 10 ep.mean score : 42.3
# Target net updated!
# 10 ep.mean score : 41.8
# Target net updated!
# 10 ep.mean score : 43.5
# Target net updated!
# 10 ep.mean score : 30.8
# Target net updated!
# 10 ep.mean score : 46.5
# Target net updated!
# 10 ep.mean score : 40.8
# Target net updated!
#
# eps_threshold: 0.1080851558018382
# steps_done:  4712366
# Mean score : 39.66
# 10 ep.mean score : 38.9
# Target net updated!
# 10 ep.mean score : 42.5
# Target net updated!
# 10 ep.mean score : 31.0
# Target net updated!
# 10 ep.mean score : 32.7
# 10 ep.mean score : 27.1
# Target net updated!
# 10 ep.mean score : 43.6
# Target net updated!
# Target net updated!
# 10 ep.mean score : 57.9
# Target net updated!
# 10 ep.mean score : 39.9
# Target net updated!
# 10 ep.mean score : 40.8
# Target net updated!
# 10 ep.mean score : 42.7
# Target net updated!
#
# eps_threshold: 0.10731446404118941
# steps_done:  4812542
# Mean score : 40.36
# 10 ep.mean score : 45.4
# Target net updated!
# 10 ep.mean score : 46.2
# Target net updated!
# 10 ep.mean score : 44.5
# Target net updated!
# 10 ep.mean score : 42.7
# Target net updated!
# 10 ep.mean score : 46.5
# Target net updated!
# 10 ep.mean score : 48.7
# Target net updated!
# 10 ep.mean score : 41.5
# Target net updated!
# 10 ep.mean score : 41.6
# Target net updated!
# 10 ep.mean score : 37.3
# Target net updated!
# 10 ep.mean score : 44.4
# Target net updated!
#
# eps_threshold: 0.10658170455910122
# steps_done:  4918102
# Mean score : 43.26
# 10 ep.mean score : 39.2
# Target net updated!
# 10 ep.mean score : 35.7
# Target net updated!
# 10 ep.mean score : 42.4
# Target net updated!
# 10 ep.mean score : 46.7
# Target net updated!
# 10 ep.mean score : 41.0
# Target net updated!
# Target net updated!
# 10 ep.mean score : 40.0
# Target net updated!
# 10 ep.mean score : 43.2
# Target net updated!
# 10 ep.mean score : 50.7
# Target net updated!
# 10 ep.mean score : 40.3
# Target net updated!
# 10 ep.mean score : 44.7
# Target net updated!
#
# eps_threshold: 0.105906761805023
# steps_done:  5026298
# Mean score : 43.53
# 10 ep.mean score : 50.6
# Target net updated!
# 10 ep.mean score : 46.3
# Target net updated!
# 10 ep.mean score : 44.8
# Target net updated!
# Target net updated!
# 10 ep.mean score : 50.4
# Target net updated!
# 10 ep.mean score : 44.3
# Target net updated!
# 10 ep.mean score : 48.7
# Target net updated!
# 10 ep.mean score : 45.8
# Target net updated!
# 10 ep.mean score : 53.1
# Target net updated!
# 10 ep.mean score : 42.2
# Target net updated!
# 10 ep.mean score : 31.4
# Target net updated!
#
# eps_threshold: 0.10528992338788698
# steps_done:  5136592
# Mean score : 44.75
# 10 ep.mean score : 40.5
# Target net updated!
# 10 ep.mean score : 36.9
# Target net updated!
# 10 ep.mean score : 40.5
# Target net updated!
# 10 ep.mean score : 40.8
# Target net updated!
# 10 ep.mean score : 37.3
# Target net updated!
# 10 ep.mean score : 38.0
# Target net updated!
# 10 ep.mean score : 40.9
# Target net updated!
# 10 ep.mean score : 41.0
# Target net updated!
# 10 ep.mean score : 40.3
# Target net updated!
# 10 ep.mean score : 42.5
# Target net updated!
#
# eps_threshold: 0.10477807030601934
# steps_done:  5238359
# Mean score : 41.29
# 10 ep.mean score : 54.7
# Target net updated!
# 10 ep.mean score : 44.2
# Target net updated!
# 10 ep.mean score : 40.7
# Target net updated!
# 10 ep.mean score : 33.5
# Target net updated!
# 10 ep.mean score : 41.6
# Target net updated!
# 10 ep.mean score : 45.0
# Target net updated!
# 10 ep.mean score : 44.4
# Target net updated!
# 10 ep.mean score : 41.1
# Target net updated!
# 10 ep.mean score : 41.6
# Target net updated!
# 10 ep.mean score : 35.1
# Target net updated!
#
# eps_threshold: 0.10432275860021284
# steps_done:  5338502
# Mean score : 40.9
# 10 ep.mean score : 41.8
# Target net updated!
# 10 ep.mean score : 45.8
# Target net updated!
# Target net updated!
# 10 ep.mean score : 45.0
# Target net updated!
# 10 ep.mean score : 41.2
# Target net updated!
# 10 ep.mean score : 42.4
# Target net updated!
# 10 ep.mean score : 43.8
# Target net updated!
# 10 ep.mean score : 48.6
# Target net updated!
# 10 ep.mean score : 49.3
# Target net updated!
# 10 ep.mean score : 46.7
# Target net updated!
# 10 ep.mean score : 48.8
# Target net updated!
#
# eps_threshold: 0.10388696156341262
# steps_done:  5444768
# Mean score : 44.74
# 10 ep.mean score : 35.8
# Target net updated!
# 10 ep.mean score : 44.8
# Target net updated!
# 10 ep.mean score : 46.2
# Target net updated!
# 10 ep.mean score : 40.6
# Target net updated!
# 10 ep.mean score : 40.1
# Target net updated!
# 10 ep.mean score : 52.7
# Target net updated!
# 10 ep.mean score : 42.1
# Target net updated!
# Target net updated!
# 10 ep.mean score : 47.0
# Target net updated!
# 10 ep.mean score : 49.8
# Target net updated!
# 10 ep.mean score : 54.5
# Target net updated!
#
# eps_threshold: 0.10348253251504408
# steps_done:  5554636
# Mean score : 46.76
# 10 ep.mean score : 49.8
# Target net updated!
# 10 ep.mean score : 60.2
# Target net updated!
# 10 ep.mean score : 42.0
# Target net updated!
# 10 ep.mean score : 46.3
# Target net updated!
# 10 ep.mean score : 48.4
# Target net updated!
# Target net updated!
# 10 ep.mean score : 51.2
# Target net updated!
# 10 ep.mean score : 47.2
# Target net updated!
# 10 ep.mean score : 50.6
# Target net updated!
# 10 ep.mean score : 44.8
# Target net updated!
# 10 ep.mean score : 47.4
# Target net updated!
#
# eps_threshold: 0.1031182650184656
# steps_done:  5665119
# Mean score : 47.99
# 10 ep.mean score : 41.8
# Target net updated!
# 10 ep.mean score : 58.8
# Target net updated!
# 10 ep.mean score : 46.9
# Target net updated!
# 10 ep.mean score : 61.2
# Target net updated!
# Target net updated!
# 10 ep.mean score : 67.1
# Target net updated!
# 10 ep.mean score : 53.5
# Target net updated!
# 10 ep.mean score : 53.1
# Target net updated!
# 10 ep.mean score : 51.8
# Target net updated!
# 10 ep.mean score : 52.7
# Target net updated!
# 10 ep.mean score : 45.6
# Target net updated!
#
# eps_threshold: 0.10278545089999411
# steps_done:  5777986
# Mean score : 54.03
# 10 ep.mean score : 49.6
# Target net updated!
# 10 ep.mean score : 48.0
# Target net updated!
# Target net updated!
# 10 ep.mean score : 58.6
# Target net updated!
# 10 ep.mean score : 46.9
# Target net updated!
# 10 ep.mean score : 47.9
# Target net updated!
# 10 ep.mean score : 45.7
# Target net updated!
# 10 ep.mean score : 46.8
# Target net updated!
# 10 ep.mean score : 45.4
# Target net updated!
# 10 ep.mean score : 51.5
# Target net updated!
# 10 ep.mean score : 72.6
# Target net updated!
#
# eps_threshold: 0.10249178111831174
# steps_done:  5889398
# Mean score : 51.17
# 10 ep.mean score : 48.3
# Target net updated!
# Target net updated!
# 10 ep.mean score : 54.4
# Target net updated!
# 10 ep.mean score : 48.3
# Target net updated!
# 10 ep.mean score : 52.3
# Target net updated!
# 10 ep.mean score : 47.1
# Target net updated!
# 10 ep.mean score : 70.1
# Target net updated!
# 10 ep.mean score : 46.1
# Target net updated!
# 10 ep.mean score : 48.8
# Target net updated!
# Target net updated!
# 10 ep.mean score : 51.1
# Target net updated!
# 10 ep.mean score : 64.1
# Target net updated!
#
# eps_threshold: 0.1022251131390225
# steps_done:  6002588
# Mean score : 53.35
# 10 ep.mean score : 51.2
# Target net updated!
# 10 ep.mean score : 52.9
# Target net updated!
# 10 ep.mean score : 55.5
# Target net updated!
# 10 ep.mean score : 64.8
# Target net updated!
# 10 ep.mean score : 43.1
# Target net updated!
# 10 ep.mean score : 44.5
# Target net updated!
# Target net updated!
# 10 ep.mean score : 53.3
# Target net updated!
# 10 ep.mean score : 43.5
# Target net updated!
# 10 ep.mean score : 51.2
# Target net updated!
# 10 ep.mean score : 38.9
# Target net updated!
#
# eps_threshold: 0.10199113686254412
# steps_done:  6113690
# Mean score : 51.04
# 10 ep.mean score : 62.7
# Target net updated!
# 10 ep.mean score : 80.5
# Target net updated!
# 10 ep.mean score : 54.8
# Target net updated!
# 10 ep.mean score : 57.6
# Target net updated!
# 10 ep.mean score : 46.3
# Target net updated!
# Target net updated!
# 10 ep.mean score : 65.2
# Target net updated!
# 10 ep.mean score : 44.8
# Target net updated!
# 10 ep.mean score : 54.2
# Target net updated!
# 10 ep.mean score : 49.3
# Target net updated!
# 10 ep.mean score : 78.0
# Target net updated!
#
# eps_threshold: 0.10177443801818772
# steps_done:  6228912
# Mean score : 59.76
# 10 ep.mean score : 66.9
# Target net updated!
# Target net updated!
# 10 ep.mean score : 50.4
# Target net updated!
# 10 ep.mean score : 87.2
# Target net updated!
# 10 ep.mean score : 48.3
# Target net updated!
# 10 ep.mean score : 54.3
# Target net updated!
# 10 ep.mean score : 53.4
# Target net updated!
# 10 ep.mean score : 54.5
# Target net updated!
# Target net updated!
# 10 ep.mean score : 66.6
# Target net updated!
# 10 ep.mean score : 43.9
# Target net updated!
# 10 ep.mean score : 57.3
# Target net updated!
#
# eps_threshold: 0.10157924796676059
# steps_done:  6345447
# Mean score : 57.08
# 10 ep.mean score : 54.9
# Target net updated!
# 10 ep.mean score : 53.1
# Target net updated!
# 10 ep.mean score : 52.8
# Target net updated!
# Target net updated!
# 10 ep.mean score : 86.7
# Target net updated!
# 10 ep.mean score : 53.0
# Target net updated!
# 10 ep.mean score : 78.7
# Target net updated!
# 10 ep.mean score : 47.9
# Target net updated!
# 10 ep.mean score : 48.2
# Target net updated!
# 10 ep.mean score : 46.2
# Target net updated!
# 10 ep.mean score : 52.0
# Target net updated!
# Target net updated!
#
# eps_threshold: 0.10140739821650727
# steps_done:  6460653
# Mean score : 57.53
# 10 ep.mean score : 56.7
# Target net updated!
# 10 ep.mean score : 59.4
# Target net updated!
# 10 ep.mean score : 48.8
# Target net updated!
# 10 ep.mean score : 49.6
# Target net updated!
# 10 ep.mean score : 47.9
# Target net updated!
# 10 ep.mean score : 58.0
# Target net updated!
# Target net updated!
# 10 ep.mean score : 61.8
# Target net updated!
# 10 ep.mean score : 58.6
# Target net updated!
# 10 ep.mean score : 47.3
# Target net updated!
# 10 ep.mean score : 56.1
# Target net updated!
#
# eps_threshold: 0.10125550861741599
# steps_done:  6574855
# Mean score : 53.13
# 10 ep.mean score : 43.8
# Target net updated!
# 10 ep.mean score : 47.9
# Target net updated!
# 10 ep.mean score : 44.6
# Target net updated!
# 10 ep.mean score : 59.7
# Target net updated!
# 10 ep.mean score : 53.4
# Target net updated!
# Target net updated!
# 10 ep.mean score : 55.6
# Target net updated!
# 10 ep.mean score : 47.1
# Target net updated!
# 10 ep.mean score : 61.0
# Target net updated!
# 10 ep.mean score : 73.9
# Target net updated!
# 10 ep.mean score : 71.5
# Target net updated!
# Target net updated!
#
# eps_threshold: 0.10111871953989225
# steps_done:  6690211
# Mean score : 60.43
# 10 ep.mean score : 89.6
# Target net updated!
# 10 ep.mean score : 67.1
# Target net updated!
# 10 ep.mean score : 57.0
# Target net updated!
# 10 ep.mean score : 73.8
# Target net updated!
# 10 ep.mean score : 62.6
# Target net updated!
# 10 ep.mean score : 63.6
# Target net updated!
# 10 ep.mean score : 49.7
# Target net updated!
# 10 ep.mean score : 48.5
# Target net updated!
# Target net updated!
# 10 ep.mean score : 51.6
# Target net updated!
# 10 ep.mean score : 76.2
# Target net updated!
#
# eps_threshold: 0.10099857278276893
# steps_done:  6803824
# Mean score : 60.97
# 10 ep.mean score : 59.6
# Target net updated!
# 10 ep.mean score : 55.5
# Target net updated!
# 10 ep.mean score : 77.9
# Target net updated!
# 10 ep.mean score : 48.9
# Target net updated!
# 10 ep.mean score : 49.3
# Target net updated!
# Target net updated!
# 10 ep.mean score : 80.8
# Target net updated!
# 10 ep.mean score : 58.1
# Target net updated!
# 10 ep.mean score : 49.4
# Target net updated!
# 10 ep.mean score : 58.5
# Target net updated!
# 10 ep.mean score : 54.2
# Target net updated!
#
# eps_threshold: 0.10089147022885751
# steps_done:  6917279
# Mean score : 59.59
# 10 ep.mean score : 63.3
# Target net updated!
# 10 ep.mean score : 63.5
# Target net updated!
# 10 ep.mean score : 53.7
# Target net updated!
# Target net updated!
# 10 ep.mean score : 59.3
# Target net updated!
# 10 ep.mean score : 79.2
# Target net updated!
# 10 ep.mean score : 54.4
# Target net updated!
# 10 ep.mean score : 50.3
# Target net updated!
# 10 ep.mean score : 96.5
# Target net updated!
# 10 ep.mean score : 58.2
# Target net updated!
# Target net updated!
# 10 ep.mean score : 54.1
# Target net updated!
#
# eps_threshold: 0.10079437611241393
# steps_done:  7032594
# Mean score : 63.28
# 10 ep.mean score : 63.6
# Target net updated!
# 10 ep.mean score : 59.0
# Target net updated!
# 10 ep.mean score : 60.4
# Target net updated!
# 10 ep.mean score : 56.3
# Target net updated!
# Target net updated!
# 10 ep.mean score : 71.1
# Target net updated!
# 10 ep.mean score : 55.1
# Target net updated!
# 10 ep.mean score : 57.0
# Target net updated!
# 10 ep.mean score : 77.1
# Target net updated!
# 10 ep.mean score : 47.5
# Target net updated!
# 10 ep.mean score : 56.6
# Target net updated!
# Target net updated!
#
# eps_threshold: 0.10070583044256239
# steps_done:  7150776
# Mean score : 62.49
# 10 ep.mean score : 84.8
# Target net updated!
# 10 ep.mean score : 81.6
# Target net updated!
# 10 ep.mean score : 63.0
# Target net updated!
# 10 ep.mean score : 76.0
# Target net updated!
# 10 ep.mean score : 69.1
# Target net updated!
# Target net updated!
# 10 ep.mean score : 64.5
# Target net updated!
# 10 ep.mean score : 67.9
# Target net updated!
# 10 ep.mean score : 61.3
# Target net updated!
# 10 ep.mean score : 58.3
# Target net updated!
# Target net updated!
# 10 ep.mean score : 46.4
# Target net updated!
#
# eps_threshold: 0.10062578886778767
# steps_done:  7271138
# Mean score : 64.33
# 10 ep.mean score : 55.2
# Target net updated!
# 10 ep.mean score : 54.8
# Target net updated!
# 10 ep.mean score : 57.2
# Target net updated!
# 10 ep.mean score : 89.5
# Target net updated!
# 10 ep.mean score : 66.3
# Target net updated!
# Target net updated!
# 10 ep.mean score : 56.7
# Target net updated!
# 10 ep.mean score : 57.5
# Target net updated!
# 10 ep.mean score : 53.4
# Target net updated!
# 10 ep.mean score : 57.0
# Target net updated!
# 10 ep.mean score : 56.4
# Target net updated!
#
# eps_threshold: 0.10055670197468354
# steps_done:  7388121
# Mean score : 60.72
# 10 ep.mean score : 58.4
# Target net updated!
# Target net updated!
# 10 ep.mean score : 81.2
# Target net updated!
# 10 ep.mean score : 61.8
# Target net updated!
# 10 ep.mean score : 67.2
# Target net updated!
# 10 ep.mean score : 65.4
# Target net updated!
# Target net updated!
# 10 ep.mean score : 82.9
# Target net updated!
# 10 ep.mean score : 56.2
# Target net updated!
# 10 ep.mean score : 59.7
# Target net updated!
# 10 ep.mean score : 77.3
# Target net updated!
# 10 ep.mean score : 53.5
# Target net updated!
# Target net updated!
#
# eps_threshold: 0.10049182946586216
# steps_done:  7512019
# Mean score : 68.38
# 10 ep.mean score : 78.6
# Target net updated!
# 10 ep.mean score : 53.9
# Target net updated!
# 10 ep.mean score : 80.3
# Target net updated!
# 10 ep.mean score : 81.2
# Target net updated!
# Target net updated!
# 10 ep.mean score : 65.2
# Target net updated!
# 10 ep.mean score : 91.7
# Target net updated!
# 10 ep.mean score : 54.1
# Target net updated!
# 10 ep.mean score : 77.2
# Target net updated!
# 10 ep.mean score : 55.9
# Target net updated!
# 10 ep.mean score : 52.3
# Target net updated!
# Target net updated!
#
# eps_threshold: 0.10043688370670772
# steps_done:  7630484
# Mean score : 67.22
# 10 ep.mean score : 60.4
# Target net updated!
# 10 ep.mean score : 77.1
# Target net updated!
# 10 ep.mean score : 75.1
# Target net updated!
# 10 ep.mean score : 64.5
# Target net updated!
# 10 ep.mean score : 65.0
# Target net updated!
# Target net updated!
# 10 ep.mean score : 67.0
# Target net updated!
# 10 ep.mean score : 63.7
# Target net updated!
# 10 ep.mean score : 61.7
# Target net updated!
# 10 ep.mean score : 72.0
# Target net updated!
# Target net updated!
# 10 ep.mean score : 68.4
# Target net updated!
#
# eps_threshold: 0.1003868399502747
# steps_done:  7752140
# Mean score : 67.88
# 10 ep.mean score : 64.3
# Target net updated!
# 10 ep.mean score : 56.0
# Target net updated!
# 10 ep.mean score : 87.6
# Target net updated!
# 10 ep.mean score : 67.2
# Target net updated!
# Target net updated!
# 10 ep.mean score : 84.3
# Target net updated!
# 10 ep.mean score : 62.8
# Target net updated!
# 10 ep.mean score : 61.0
# Target net updated!
# 10 ep.mean score : 82.3
# Target net updated!
# 10 ep.mean score : 72.0
# Target net updated!
# Target net updated!
# 10 ep.mean score : 79.2
# Target net updated!
#
# eps_threshold: 0.10034277252759469
# steps_done:  7873084
# Mean score : 70.76
# 10 ep.mean score : 55.2
# Target net updated!
# 10 ep.mean score : 66.6
# Target net updated!
# 10 ep.mean score : 93.1
# Target net updated!
# Target net updated!
# 10 ep.mean score : 61.2
# Target net updated!
# 10 ep.mean score : 50.9
# Target net updated!
# 10 ep.mean score : 61.5
# Target net updated!
# 10 ep.mean score : 56.2
# Target net updated!
# 10 ep.mean score : 83.1
# Target net updated!
# 10 ep.mean score : 87.9
# Target net updated!
# Target net updated!
# 10 ep.mean score : 63.9
# Target net updated!
#
# eps_threshold: 0.10030396149807204
# steps_done:  7993250
# Mean score : 68.22
# 10 ep.mean score : 57.8
# Target net updated!
# 10 ep.mean score : 73.9
# Target net updated!
# 10 ep.mean score : 63.1
# Target net updated!
# 10 ep.mean score : 64.1
# Target net updated!
# Target net updated!
# 10 ep.mean score : 66.6
# Target net updated!
# 10 ep.mean score : 55.3
# Target net updated!
# 10 ep.mean score : 66.1
# Target net updated!
# Target net updated!
# 10 ep.mean score : 76.2
# Target net updated!
# 10 ep.mean score : 63.4
# Target net updated!
# 10 ep.mean score : 58.7
# Target net updated!
#
# eps_threshold: 0.10026836608636963
# steps_done:  8117799
# Mean score : 67.15
# 10 ep.mean score : 84.1
# Target net updated!
# Target net updated!
# 10 ep.mean score : 68.8
# Target net updated!
# 10 ep.mean score : 73.8
# Target net updated!
# 10 ep.mean score : 71.7
# Target net updated!
# 10 ep.mean score : 61.1
# Target net updated!
# 10 ep.mean score : 64.4
# Target net updated!
# Target net updated!
# 10 ep.mean score : 92.9
# Target net updated!
# 10 ep.mean score : 77.9
# Target net updated!
# 10 ep.mean score : 79.0
# Target net updated!
# Target net updated!
# 10 ep.mean score : 94.1
# Target net updated!
#
# eps_threshold: 0.10023655601796279
# steps_done:  8243966
# Mean score : 74.64
# 10 ep.mean score : 62.7
# Target net updated!
# 10 ep.mean score : 72.5
# Target net updated!
# 10 ep.mean score : 69.9
# Target net updated!
# Target net updated!
# 10 ep.mean score : 73.6
# Target net updated!
# 10 ep.mean score : 73.8
# Target net updated!
# 10 ep.mean score : 86.6
# Target net updated!
# 10 ep.mean score : 111.3
# Target net updated!
# Target net updated!
# 10 ep.mean score : 61.1
# Target net updated!
# 10 ep.mean score : 94.1
# Target net updated!
# 10 ep.mean score : 55.4
# Target net updated!
#
# eps_threshold: 0.10020945230289728
# steps_done:  8365655
# Mean score : 77.78
# 10 ep.mean score : 79.5
# Target net updated!
# 10 ep.mean score : 89.8
# Target net updated!
# 10 ep.mean score : 86.2
# Target net updated!
# Target net updated!
# 10 ep.mean score : 73.3
# Target net updated!
# 10 ep.mean score : 77.0
# Target net updated!
# 10 ep.mean score : 72.2
# Target net updated!
# 10 ep.mean score : 65.4
# Target net updated!
# 10 ep.mean score : 64.3
# Target net updated!
# Target net updated!
# 10 ep.mean score : 64.5
# Target net updated!
# 10 ep.mean score : 90.0
# Target net updated!
#
# eps_threshold: 0.1001855562447532
# steps_done:  8486793
# Mean score : 74.79
# 10 ep.mean score : 65.2
# Target net updated!
# 10 ep.mean score : 62.6
# Target net updated!
# 10 ep.mean score : 75.1
# Target net updated!
# 10 ep.mean score : 55.1
# Target net updated!
# Target net updated!
# 10 ep.mean score : 78.7
# Target net updated!
# 10 ep.mean score : 66.3
# Target net updated!
# 10 ep.mean score : 65.9
# Target net updated!
# 10 ep.mean score : 62.0
# Target net updated!
# Target net updated!
# 10 ep.mean score : 69.5
# Target net updated!
# 10 ep.mean score : 63.6
# Target net updated!
#
# eps_threshold: 0.10016499349391525
# steps_done:  8604245
# Mean score : 66.16
# 10 ep.mean score : 62.8
# Target net updated!
# 10 ep.mean score : 79.8
# Target net updated!
# 10 ep.mean score : 63.2
# Target net updated!
# Target net updated!
# 10 ep.mean score : 105.7
# Target net updated!
# 10 ep.mean score : 59.9
# Target net updated!
# 10 ep.mean score : 73.6
# Target net updated!
# Target net updated!
# 10 ep.mean score : 89.9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-99af03b0cd3a> in <module>()
#      24         # done - флаг окончания эпизода
#      25         # info - важная системная информация
# ---> 26         state_holder.push(get_screen())
#      27         next_state = state_holder.get()
#      28         # Код обработки перехода
#
# <ipython-input-4-58f338a0d529> in get_screen()
#      10 def get_screen():
#      11     screen = env.render(mode='rgb_array')
# ---> 12     screen = np.dot(screen[...,:3], [0.299, 0.587, 0.114])
#      13     screen = screen[30:195,:]
#      14     screen = np.ascontiguousarray(screen, dtype=np.uint8).reshape(screen.shape[0],screen.shape[1],1)
#
# KeyboardInterrupt:

# %%
len(train_rewards)
# Out:
# 13060

# %%
plot_rewards(train_rewards)

# %%
# Задание 3. Заполнить пропуски в нижеприведенном коде.
optimizer = optim.Adam(policy_net.parameters(), lr=0.000001)
NUM_EPISODES = 10000
EPS_END = 0.02
for e in tqdm.tqdm_notebook(range(NUM_EPISODES)):
    env.reset()
    lives = 5
    ep_rewards = []
    state_holder.push(get_screen())
    
    for t in count():
        state = state_holder.get()
        # Рассчет eps_threshold'а для e-greedy
        eps_threshold = EPS_END + (EPS_START - EPS_END) * math.exp(-1. * steps_done / EPS_DECAY)
        action = select_action(state, eps_threshold)
        steps_done += 1
        
        # Шаг одного кадра игры 
        _, reward, done, info = env.step(action.item())
        life = info['ale.lives']
        ep_rewards.append(reward)
        reward = torch.tensor([reward], device=device)
        # где:
        # reward - награда, полученная в рамках последнего действия
        # done - флаг окончания эпизода
        # info - важная системная информация
        state_holder.push(get_screen())
        next_state = state_holder.get()
        # Код обработки перехода
        # Работа с ReplayMemory
        if not done:
            new_reward = reward
            next_state, lives = (None, life) if life < lives else (next_state, lives)
            memory.push(state.to('cpu'), action, next_state, new_reward)
            state = next_state
        else:
            next_state = None
            new_reward = torch.zeros_like(reward)
            memory.push(state.to('cpu'), action, next_state, new_reward)
            state = next_state
        
        # Задание 3.1. Необходимо дополниь код следующим трюком, который значительно
        # улучшает сходимость обучения. В случае, если эпизод не закончился, но агент на 
        # очередном шаге потерял жизнь, то такой переход надо класть в ReplayMemory как финальный.
        # При этом, необходимо далее продолжать эпизод игры, пока не получите done == True
        # Тет самым вы научите агента понимать, что терять жизни по дороге - плохо.
        
        # Шаг оптимизации
        if (steps_done > STEPS_BEFORE_TRAIN) and steps_done % OPTIMIZE_MODEL_STEP == 0:
            BATCH_SIZE = 32
            optimize_model()
        if e % 100 == 99 and  t == 0:
            print('\neps_threshold:', eps_threshold)
            print('steps_done: ', steps_done)
            # Средний reward по последним 100 эпизодам
            print("Mean score : {}".format(np.mean(train_rewards[-100:])))
        if e % 10 == 9 and  t == 0:
            print("10 ep.mean score : {}".format(np.mean(train_rewards[-10:])))
        if t > 18000:
            break
        # Шаг обновления target'сети
        if steps_done % TARGET_UPDATE == 0:
            print("Target net updated!")
            target_net.load_state_dict(policy_net.state_dict())
        
        # Код завершающий эпизод игры/обучения
        if done:
            train_rewards.append(np.sum(ep_rewards))
            break
